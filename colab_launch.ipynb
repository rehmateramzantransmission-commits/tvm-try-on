# %% [markdown]
# # 🚀 TVM Smart Mirror — Google Colab 1-Click GPU Launcher
# **Decart Lucy AI World Model Architecture & Photorealistic Virtual Try-On**
#
# ### Instructions:
# 1. Go to **Runtime -> Change runtime type -> Select T4 GPU**.
# 2. Click **Run All** or press **Play (▶)** on the code cell below!
# 3. Open the generated `✨ PUBLIC APP URL` in your Chrome browser.

# %%
# 1. Clone repository & setup workspace
# !git clone https://github.com/your-repo/tvm-live-try-on.git /content/tvm-live-try-on || true
# %cd /content/tvm-live-try-on

# 2. Install dependencies
# !pip install -q fastapi uvicorn websockets opencv-python-headless mediapipe numpy pillow pyngrok gradio_client

# 3. Run Colab Server Launcher with pre-configured HF & Ngrok credentials
# !python run_colab.py
